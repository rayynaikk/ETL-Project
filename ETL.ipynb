# %%
#pip install spotipy

# %%
import spotipy
from spotipy.oauth2 import SpotifyClientCredentials
import pandas as pd

# %%
client_credentials_manager=SpotifyClientCredentials(client_id='4d7c21028c174ce08a88ad273f9bfaa4', client_secret='11b1d09562a7433fb3abc3477c25b857')

# %%
sp = spotipy.Spotify(client_credentials_manager = client_credentials_manager)

# %%
playlist_link = "https://open.spotify.com/playlist/37i9dQZEVXbNG2KDcFcKOF?si=1333723a6eff4b71"

# %%
playlist_uri = playlist_link.split("/")[-1].split("?")[0]

# %%
data=sp.playlist_tracks(playlist_uri)

# %%
data['items']
# Out:
# [{'added_at': '2024-07-12T08:43:29Z',
#   'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/'},
#    'href': 'https://api.spotify.com/v1/users/',
#    'id': '',
#    'type': 'user',
#    'uri': 'spotify:user:'},
#   'is_local': False,
#   'primary_color': None,
#   'track': {'preview_url': None,
#    'available_markets': ['AR',
#     'AU',
#     'AT',
#     'BE',
#     'BO',
#     'BR',
#     'BG',
#     'CA',
#     'CL',
#     'CO',
#     'CR',
#     'CY',
#     'CZ',
#     'DK',
#     'DO',
#     'DE',
#     'EC',
#     'EE',
#     'SV',
#     'FI',
#     'FR',
#     'GR',
#     'GT',
#     'HN',
#     'HK',
#     'HU',
#     'IS',
#     'IE',
#     'IT',
#     'LV',
#     'LT',
#     'LU',
#     'MY',
#     'MT',
#     'MX',
#     'NL',
#     'NZ',
#     'NI',
#     'NO',
#     'PA',
#     'PY',
#     'PE',
#     'PH',
#     'PL',
#     'PT',
#     'SG',
#     'SK',
#     'ES',
#     'SE',
#     'CH',
#     'TW',
#     'TR',
#     'UY',
#     'US',
# ...

# %%
len(data['items'])
# Out:
# 50

# %%
data['items'][0]['track']['album']
# Out:
# {'available_markets': ['AR',
#   'AU',
#   'AT',
#   'BE',
#   'BO',
#   'BR',
#   'BG',
#   'CA',
#   'CL',
#   'CO',
#   'CR',
#   'CY',
#   'CZ',
#   'DK',
#   'DO',
#   'DE',
#   'EC',
#   'EE',
#   'SV',
#   'FI',
#   'FR',
#   'GR',
#   'GT',
#   'HN',
#   'HK',
#   'HU',
#   'IS',
#   'IE',
#   'IT',
#   'LV',
#   'LT',
#   'LU',
#   'MY',
#   'MT',
#   'MX',
#   'NL',
#   'NZ',
#   'NI',
#   'NO',
#   'PA',
#   'PY',
#   'PE',
#   'PH',
#   'PL',
#   'PT',
#   'SG',
#   'SK',
#   'ES',
#   'SE',
#   'CH',
#   'TW',
#   'TR',
#   'UY',
#   'US',
#   'GB',
#   'AD',
#   'LI',
#   'MC',
#   'ID',
#   'JP',
#   'TH',
#   'VN',
#   'RO',
#   'IL',
#   'ZA',
#   'SA',
#   'AE',
#   'BH',
#   'QA',
#   'OM',
#   'KW',
#   'EG',
#   'MA',
#   'DZ',
#   'TN',
#   'LB',
#   'JO',
#   'PS',
#   'IN',
#   'KZ',
#   'MD',
#   'UA',
#   'AL',
#   'BA',
#   'HR',
#   'ME',
#   'MK',
#   'RS',
#   'SI',
#   'KR',
#   'BD',
#   'PK',
#   'LK',
#   'GH',
#   'KE',
#   'NG',
#   'TZ',
# ...

# %%
data['items'][0]['track']['album']['id']
# Out:
# '5quMTd5zeI9yW5UDua8wS4'

# %%
data['items'][0]['track']['album']['name']
# Out:
# 'Espresso'

# %%
data['items'][0]['track']['album']['release_date']
# Out:
# '2024-04-12'

# %%
data['items'][0]['track']['album']['total_tracks']
# Out:
# 1

# %%
data['items'][0]['track']['album']['external_urls']
# Out:
# {'spotify': 'https://open.spotify.com/album/5quMTd5zeI9yW5UDua8wS4'}

# %%
data['items'][0]['track']['album']['external_urls']['spotify']
# Out:
# 'https://open.spotify.com/album/5quMTd5zeI9yW5UDua8wS4'

# %%
#access all the albums using for Loop and save it into a dictionary
#later, append all the dictionary into one list
album_list = []
for row in data['items']:
    album_id = row['track']['album']['id']
    album_name = row['track']['album']['name']
    album_release_date = row['track']['album']['release_date']
    album_total_tracks = row['track']['album']['total_tracks']
    album_url = row['track']['album']['external_urls']['spotify']
    album_element = {'album id': album_id, 'album name': album_name, 'release_date':album_release_date, 'total_tracks':album_total_tracks, 'url':album_url}
    album_list.append(album_element)

# %%
album_list
# Out:
# [{'album id': '5quMTd5zeI9yW5UDua8wS4',
#   'album name': 'Espresso',
#   'release_date': '2024-04-12',
#   'total_tracks': 1,
#   'url': 'https://open.spotify.com/album/5quMTd5zeI9yW5UDua8wS4'},
#  {'album id': '7aJuG4TFXa2hmE4z1yxc3n',
#   'album name': 'HIT ME HARD AND SOFT',
#   'release_date': '2024-05-17',
#   'total_tracks': 10,
#   'url': 'https://open.spotify.com/album/7aJuG4TFXa2hmE4z1yxc3n'},
#  {'album id': '5bBaoign62r1i7OV8w7mi9',
#   'album name': 'Please Please Please',
#   'release_date': '2024-06-06',
#   'total_tracks': 2,
#   'url': 'https://open.spotify.com/album/5bBaoign62r1i7OV8w7mi9'},
#  {'album id': '5JjnoGJyOxfSZUZtk2rRwZ',
#   'album name': 'Not Like Us',
#   'release_date': '2024-05-04',
#   'total_tracks': 1,
#   'url': 'https://open.spotify.com/album/5JjnoGJyOxfSZUZtk2rRwZ'},
#  {'album id': '5tSQtQGkrCJx3hoQxmLgfM',
#   'album name': 'Gata Only',
#   'release_date': '2024-02-02',
#   'total_tracks': 1,
# ...

# %%
data['items'][1]['track']['artists']
# Out:
# [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6qqNVTkY8uBg9cP3Jd7DAH'},
#   'href': 'https://api.spotify.com/v1/artists/6qqNVTkY8uBg9cP3Jd7DAH',
#   'id': '6qqNVTkY8uBg9cP3Jd7DAH',
#   'name': 'Billie Eilish',
#   'type': 'artist',
#   'uri': 'spotify:artist:6qqNVTkY8uBg9cP3Jd7DAH'}]

# %%
artist_list = []
for row in data['items']:
    for key, value in row.items ():
        if key == 'track':
            for artist in value['artists']:
                artist_dict = {'artist_id':artist['id'], 'artist_name':artist['name'], 'external_url':artist["href"]}
                artist_list.append(artist_dict)

# %%
artist_list
# Out:
# [{'artist_id': '74KM79TiuVKeVCqs8QtB0B',
#   'artist_name': 'Sabrina Carpenter',
#   'external_url': 'https://api.spotify.com/v1/artists/74KM79TiuVKeVCqs8QtB0B'},
#  {'artist_id': '6qqNVTkY8uBg9cP3Jd7DAH',
#   'artist_name': 'Billie Eilish',
#   'external_url': 'https://api.spotify.com/v1/artists/6qqNVTkY8uBg9cP3Jd7DAH'},
#  {'artist_id': '74KM79TiuVKeVCqs8QtB0B',
#   'artist_name': 'Sabrina Carpenter',
#   'external_url': 'https://api.spotify.com/v1/artists/74KM79TiuVKeVCqs8QtB0B'},
#  {'artist_id': '2YZyLoL8N0Wb9xBt1NhZWg',
#   'artist_name': 'Kendrick Lamar',
#   'external_url': 'https://api.spotify.com/v1/artists/2YZyLoL8N0Wb9xBt1NhZWg'},
#  {'artist_id': '7CvTknweLr9feJtRGrpDBy',
#   'artist_name': 'FloyyMenor',
#   'external_url': 'https://api.spotify.com/v1/artists/7CvTknweLr9feJtRGrpDBy'},
#  {'artist_id': '1Yj5Xey7kTwvZla8sqdsdE',
#   'artist_name': 'Cris Mj',
#   'external_url': 'https://api.spotify.com/v1/artists/1Yj5Xey7kTwvZla8sqdsdE'},
# ...

# %%
song_list = []
for row in data['items']:
    song_id = row['track']['id']
    song_name = row['track']['name']
    song_duration = row['track']['duration_ms']
    song_url = row['track']['external_urls']['spotify']
    song_popularity = row['track']['popularity']
    song_added = row['added_at']
    albun_id = row['track']['album']['id']
    artist_id = row['track']['album']['artists'][0]['id']
    song_element = {'song_id':song_id, 'song_name':song_name, 'duration_ms':song_duration,'url':song_url, 'popularity':song_popularity, 'song _added': song_added, 'album_id':album_id, 'artist_id':artist_id}
    song_list.append(song_element)

# %%
album_df=pd.DataFrame.from_dict(album_list)

# %%
album_df.head()
# Out:
#                  album id            album name release_date  total_tracks  \
# 0  5quMTd5zeI9yW5UDua8wS4              Espresso   2024-04-12             1
# 1  7aJuG4TFXa2hmE4z1yxc3n  HIT ME HARD AND SOFT   2024-05-17            10
# 2  5bBaoign62r1i7OV8w7mi9  Please Please Please   2024-06-06             2
# 3  5JjnoGJyOxfSZUZtk2rRwZ           Not Like Us   2024-05-04             1
# 4  5tSQtQGkrCJx3hoQxmLgfM             Gata Only   2024-02-02             1
#
#                                                  url
# 0  https://open.spotify.com/album/5quMTd5zeI9yW5U...
# 1  https://open.spotify.com/album/7aJuG4TFXa2hmE4...
# 2  https://open.spotify.com/album/5bBaoign62r1i7O...
# 3  https://open.spotify.com/album/5JjnoGJyOxfSZUZ...
# 4  https://open.spotify.com/album/5tSQtQGkrCJx3ho...

# %%
artist_df=pd.DataFrame.from_dict(artist_list)

# %%
artist_df.head()
# Out:
#                 artist_id        artist_name  \
# 0  74KM79TiuVKeVCqs8QtB0B  Sabrina Carpenter
# 1  6qqNVTkY8uBg9cP3Jd7DAH      Billie Eilish
# 2  74KM79TiuVKeVCqs8QtB0B  Sabrina Carpenter
# 3  2YZyLoL8N0Wb9xBt1NhZWg     Kendrick Lamar
# 4  7CvTknweLr9feJtRGrpDBy         FloyyMenor
#
#                                         external_url
# 0  https://api.spotify.com/v1/artists/74KM79TiuVK...
# 1  https://api.spotify.com/v1/artists/6qqNVTkY8uB...
# 2  https://api.spotify.com/v1/artists/74KM79TiuVK...
# 3  https://api.spotify.com/v1/artists/2YZyLoL8N0W...
# 4  https://api.spotify.com/v1/artists/7CvTknweLr9...

# %%
song_df=pd.DataFrame.from_dict(song_list)

# %%
song_df.head()
# Out:
#                   song_id             song_name  duration_ms  \
# 0  2qSkIjg1o9h3YT9RAgYN75              Espresso       175459
# 1  6dOtVTDdiauQNBQEDOtlAB    BIRDS OF A FEATHER       210373
# 2  5N3hjp1WNayUPZrA8kJmJP  Please Please Please       186365
# 3  6AI3ezQ4o3HUoP6Dhudph3           Not Like Us       274192
# 4  6XjDF6nds4DE2BBbagZol6             Gata Only       222000
#
#                                                  url  popularity  \
# 0  https://open.spotify.com/track/2qSkIjg1o9h3YT9...          99
# 1  https://open.spotify.com/track/6dOtVTDdiauQNBQ...          99
# 2  https://open.spotify.com/track/5N3hjp1WNayUPZr...          98
# 3  https://open.spotify.com/track/6AI3ezQ4o3HUoP6...          97
# 4  https://open.spotify.com/track/6XjDF6nds4DE2BB...          96
#
#             song _added                album_id               artist_id
# 0  2024-07-12T08:43:29Z  2nkto6YNI4rUYTLqEwWJ3o  74KM79TiuVKeVCqs8QtB0B
# ...

# %%
album_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50 entries, 0 to 49
# Data columns (total 5 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   album id      50 non-null     object
#  1   album name    50 non-null     object
#  2   release_date  50 non-null     object
#  3   total_tracks  50 non-null     int64
#  4   url           50 non-null     object
# dtypes: int64(1), object(4)
# memory usage: 2.1+ KB

# %%
album_df=album_df.drop_duplicates(subset=['album id'])

# %%
album_df['release_date'] = pd.to_datetime(album_df ['release_date'])
# Out:
# C:\Users\RiRi\AppData\Local\Temp\ipykernel_13808\633397172.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   album_df['release_date'] = pd.to_datetime(album_df ['release_date'])

# %%
album_df['release_date'].replace('1963', '1963-01-01', inplace=True)
# Out:
# C:\Users\RiRi\AppData\Local\Temp\ipykernel_13808\1908921605.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   album_df['release_date'].replace('1963', '1963-01-01', inplace=True)

# %%
album_df
# Out:
#                   album id                                         album name  \
# 0   5quMTd5zeI9yW5UDua8wS4                                           Espresso
# 1   7aJuG4TFXa2hmE4z1yxc3n                               HIT ME HARD AND SOFT
# 2   5bBaoign62r1i7OV8w7mi9                               Please Please Please
# 3   5JjnoGJyOxfSZUZtk2rRwZ                                        Not Like Us
# 4   5tSQtQGkrCJx3hoQxmLgfM                                          Gata Only
# 5   0DLvFVIfwt3OHdK9kGeEM3             Where I've Been, Isn't Where I'm Going
# 6   2Z1gnUf3nbn6DtwZSUIH54                                MILLION DOLLAR BABY
# 7   168CdR21lfn0TTyw1Pkdcm                           Fireworks & Rollerblades
# 8   1WAjjRMfZjEXtB0lQrAw6Q                                   Good Luck, Babe!
# 9   5ylbxH7EqpsmHZCRuiYewS                       Si Antes Te Hubiera Conocido
# 10  3P4SQqMMgjqfqVxgLwtYRk                            Unreal Unearth: Unheard
# ...

# %%
song_df['song _added']=pd.to_datetime(song_df['song _added'])

# %%
song_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50 entries, 0 to 49
# Data columns (total 8 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   song_id      50 non-null     object
#  1   song_name    50 non-null     object
#  2   duration_ms  50 non-null     int64
#  3   url          50 non-null     object
#  4   popularity   50 non-null     int64
#  5   song _added  50 non-null     datetime64[ns, UTC]
#  6   album_id     50 non-null     object
#  7   artist_id    50 non-null     object
# dtypes: datetime64[ns, UTC](1), int64(2), object(5)
# memory usage: 3.2+ KB
